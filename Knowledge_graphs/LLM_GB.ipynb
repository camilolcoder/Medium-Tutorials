# %%
from neo4j import GraphDatabase
import openai

import os
import sys
project_root = os.path.abspath(os.path.join(os.getcwd(), "../"))
sys.path.append(project_root)
import keys

# %%
os.environ["OPENAI_API_KEY"] = keys.OPEN_AI_API_KEY

# %%
uri = keys.URI
username = "neo4j"
password = keys.NEO4J_PASS

# %%
def get_neo4j_schema():
    cypher_query = """
    MATCH (n)-[r]->(m) 
    RETURN DISTINCT labels(n) AS source_node, type(r) AS relationship, labels(m) AS target_node
    """
    
    driver = GraphDatabase.driver(uri, auth=(username, password))
    with driver.session() as session:
        result = session.run(cypher_query)
        schema = []
        
        for record in result:
            source = ", ".join(record["source_node"]) if record["source_node"] else "Unknown"
            relationship = record["relationship"]
            target = ", ".join(record["target_node"]) if record["target_node"] else "Unknown"
            schema.append(f"- ({source})-[:{relationship}]->({target})")
        
        return "\n".join(schema)

schema_info = get_neo4j_schema()
print("Neo4j Schema:\n", schema_info)
# Out:
# Neo4j Schema:
#  - (Chunk)-[:PART_OF]->(Document)
# - (Chunk)-[:NEXT_CHUNK]->(Chunk)
# - (Chunk)-[:HAS_ENTITY]->(Document, __Entity__, Book)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Organization, Project)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Person)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Date)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Language)
# - (Chunk)-[:SIMILAR]->(Chunk)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Title)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Organization, Institution)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Book)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Feature)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Audience)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Purpose)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Institution)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Event)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Entity, Place, City)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Place)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, People, Group)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Society)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, People)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Group)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Organization)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Characteristic)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Location)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Place, Location, Country)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Entity)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Position)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Place, Region)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Region)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, TimePeriod)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Time Period)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Concept)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Government System)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Entities)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Dynasty)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Chapter)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Historical Period)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Geographical Entity)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Political Entity)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Social Structure)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Period)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Geographical Feature)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Religion)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Religious Practice)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Political System)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Cultural Entity)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Component)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Outcome)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, System)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Record)
# - (Chunk)-[:HAS_ENTITY]->(Document, __Entity__)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Activity)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Work)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Topic)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Profession)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Date Range)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Limitation)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Belief)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Narrative)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, HistoricalEvent)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Location, Region)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Resource)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Product)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Industry)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Plant)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Place, Location)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Historical Significance)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Place, Name)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Word)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Place, Geographical Entity)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Process)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Science)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Animal)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Artifact Type)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, TimePeriod, Time Period)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Material)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Object)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Characteristic, Group)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Skill)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Structure)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Artifact)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Tool)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Culture)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, City)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Settlement)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Civilization)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Era)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, Type)
# - (Document, __Entity__, Book)-[:WRITTEN_BY]->(__Entity__, Person)
# - (Document, __Entity__, Book)-[:PUBLISHED_BY]->(__Entity__, Organization, Project)
# - (Document, __Entity__, Book)-[:HAS_AUTHOR]->(__Entity__, Person)
# - (Document, __Entity__, Book)-[:HAS_RELEASE_DATE]->(__Entity__, Date)
# - (Document, __Entity__, Book)-[:HAS_LANGUAGE]->(__Entity__, Language)
# - (Document, __Entity__, Book)-[:IS_PART_OF]->(__Entity__, Organization, Project)
# - (__Entity__, Organization, Project)-[:PROVIDES_LICENSE]->(__Entity__, License)
# - (__Entity__, Person)-[:HAS_TITLE]->(__Entity__, Title)
# - (__Entity__, Person)-[:AFFILIATED_WITH]->(__Entity__, Organization, Institution)
# - (__Entity__, Book)-[:WRITTEN_BY]->(__Entity__, Person)
# - (__Entity__, Book)-[:HAS_FEATURE]->(__Entity__, Feature)
# - (__Entity__, Book)-[:INTENDED_FOR]->(__Entity__, Purpose)
# - (__Entity__, Book)-[:HAS_AUDIENCE]->(__Entity__, Audience)
# - (__Entity__, Person)-[:AFFILIATED_WITH]->(__Entity__, Institution)
# - (__Entity__, Person)-[:GUIDED]->(__Entity__, Person)
# - (__Entity__, Person)-[:COLLEAGUE_OF]->(__Entity__, Person)
# - (__Entity__, Entity, Place, City)-[:HAS_ORIGIN]->(__Entity__, People)
# - (__Entity__, Entity, Place, City)-[:HAS_ORIGIN]->(__Entity__, Event)
# - (__Entity__, Entity, Place, City)-[:HAS_EVENT]->(__Entity__, Event)
# - (__Entity__, Entity, Place, City)-[:HAS_SOCIETY]->(__Entity__, Society)
# - (__Entity__, Entity, Place, City)-[:EXPANDED_TO]->(__Entity__, Place)
# - (__Entity__, Entity, Place, City)-[:CONQUERED]->(__Entity__, Place)
# - (__Entity__, Entity, Place, City)-[:ALLIED_WITH]->(__Entity__, Group)
# - (__Entity__, Entity, Place, City)-[:FOUGHT_WITH]->(__Entity__, People, Group)
# - (__Entity__, Entity, Place, City)-[:FOUGHT_WITH]->(__Entity__, Group)
# - (__Entity__, Entity, Place, City)-[:DISRUPTED]->(__Entity__, Group)
# - (__Entity__, Entity, Place, City)-[:HAS_HISTORY]->(Document, __Entity__, Book)
# - (__Entity__, Entity, Place, City)-[:HAS_HISTORY]->(__Entity__, Event)
# - (__Entity__, Entity, Place, City)-[:HAS_HISTORY]->(__Entity__, TimePeriod)
# - (__Entity__, Entity, Place, City)-[:HAS_CONSTITUTIONAL_DEVELOPMENT]->(__Entity__, Event)
# - (__Entity__, Entity, Place, City)-[:HAS_EARLY_REPUBLIC]->(__Entity__, Event)
# - (__Entity__, Entity, Place, City)-[:HAS_ASSEMBLY]->(__Entity__, Organization)
# - (__Entity__, Entity, Place, City)-[:HAS_MAGISTRACY_DEVELOPMENT]->(__Entity__, Event)
# - (__Entity__, Entity, Place, City)-[:HAS_PLEBEIAN_STRUGGLE]->(__Entity__, Event)
# - (__Entity__, Entity, Place, City)-[:HAS_MILITARY_SYSTEM]->(__Entity__, Characteristic)
# - (__Entity__, Entity, Place, City)-[:HAS_RELIGION_AND_SOCIETY]->(__Entity__, Characteristic)
# - (__Entity__, Entity, Place, City)-[:HAS_DOMINATION]->(__Entity__, Event)
# - (__Entity__, Entity, Place, City)-[:LOCATED_IN]->(__Entity__, Place, Location, Country)
# - (__Entity__, Entity, Place, City)-[:PRACTISED_WRITING]->(__Entity__, Time Period)
# - (__Entity__, Entity, Place, City)-[:FOUNDED_BY]->(__Entity__, Group)
# - (__Entity__, Entity, Place, City)-[:EXTENDED_DOMINION_OVER]->(__Entity__, Place)
# - (__Entity__, Entity, Place, City)-[:DOMINANT_STATE_IN]->(__Entity__, Place, Location, Country)
# - (__Entity__, People, Group)-[:APPLIED_TO]->(__Entity__, Place)
# - (__Entity__, People, Group)-[:INHABITED]->(__Entity__, Place)
# - (__Entity__, People, Group)-[:BROUGHT_INTO_RELATION_WITH]->(__Entity__, Group)
# - (__Entity__, People)-[:ASSOCIATED_WITH]->(__Entity__, Event)
# - (__Entity__, Group)-[:CONQUERED]->(__Entity__, Place)
# - (__Entity__, Group)-[:ENGAGED_IN]->(__Entity__, Event)
# - (__Entity__, Group)-[:ESTABLISHED]->(__Entity__, Organization)
# - (__Entity__, Group)-[:BELIEVED]->(__Entity__, Belief)
# - (__Entity__, Event)-[:INVOLVED]->(__Entity__, Entity, Place, City)
# - (__Entity__, Event)-[:OCCURRED_IN]->(__Entity__, Place, Location, Country)
# - (__Entity__, Event)-[:CLOSE_OF]->(__Entity__, Activity)
# - (__Entity__, Place, Location, Country)-[:HAS_FEATURE]->(__Entity__, Characteristic)
# - (__Entity__, Place, Location, Country)-[:LOCATION_IN]->(__Entity__, Location)
# - (__Entity__, Place, Location, Country)-[:FACES]->(__Entity__, Location)
# - (__Entity__, Place, Location, Country)-[:HAS_REGION]->(__Entity__, Region)
# - (__Entity__, Place, Location, Country)-[:HAS_LENGTH]->(__Entity__, Characteristic)
# - (__Entity__, Place, Location, Country)-[:HAS_CHARACTERISTIC]->(__Entity__, Characteristic)
# - (__Entity__, Place, Location, Country)-[:HAS_WEALTH]->(__Entity__, Characteristic)
# - (__Entity__, Place, Location, Country)-[:WAS_UNIFIED_BY]->(__Entity__, Entity, Place, City)
# - (__Entity__, Place, Location, Country)-[:DERIVED_FROM]->(__Entity__, Place, Name)
# - (__Entity__, Place, Location, Country)-[:ACCESSIBLE_TO]->(__Entity__, Characteristic)
# - (__Entity__, Place, Location, Country)-[:SUBJECTED_TO]->(__Entity__, Event)
# - (__Entity__, Place, Location, Country)-[:BORDERED_BY]->(__Entity__, Location)
# - (__Entity__, Place, Location, Country)-[:OCCUPIED_BY]->(__Entity__, Group)
# - (__Entity__, Place, Location, Country)-[:LANGUAGES_SPOKEN]->(__Entity__, Characteristic)
# - (__Entity__, Place, Location, Country)-[:CULTURAL_CONDITIONS]->(__Entity__, Characteristic)
# - (__Entity__, Place, Location, Country)-[:ENTERED_BY]->(__Entity__, Group)
# - (__Entity__, Place, Location, Country)-[:HAD_RACIAL_UNITY]->(__Entity__, Group)
# - (__Entity__, Place, Location, Country)-[:BELIEVED_TO_HAVE_HELD]->(__Entity__, Geographical Feature)
# - (__Entity__, Event)-[:OCCURRED_IN]->(__Entity__, Location)
# - (__Entity__, Event)-[:INVOLVED]->(__Entity__, Entity)
# - (__Entity__, Event)-[:TOOK_PLACE_IN]->(__Entity__, Location)
# - (__Entity__, Event)-[:TOOK_PLACE_IN]->(__Entity__, Place, Location, Country)
# - (__Entity__, Person)-[:ASSOCIATED_WITH]->(__Entity__, Concept)
# - (__Entity__, Person)-[:HAD_ROLE]->(__Entity__, Position)
# - (__Entity__, Person)-[:HELD_POSITION]->(__Entity__, Position)
# - (__Entity__, Person)-[:ASSOCIATED_WITH]->(__Entity__, Event)
# - (__Entity__, Group)-[:ASSOCIATED_WITH]->(__Entity__, Event)
# - (__Entity__, Event)-[:PART_OF]->(__Entity__, Event)
# - (__Entity__, Event)-[:ASSOCIATED_WITH]->(__Entity__, Person)
# - (__Entity__, Event)-[:ALSO_KNOWN_AS]->(__Entity__, Event)
# - (__Entity__, Group)-[:PARTICIPATED_IN]->(__Entity__, Event)
# - (__Entity__, Person)-[:COMMANDS_AGAINST]->(__Entity__, Group)
# - (__Entity__, Person)-[:COMMANDS_IN]->(__Entity__, Region)
# - (__Entity__, Person)-[:COALITION_WITH]->(__Entity__, Person)
# - (__Entity__, Person)-[:CONQUERED]->(__Entity__, Place, Region)
# - (__Entity__, Person)-[:INVOLVED_IN]->(__Entity__, Event)
# - (__Entity__, Person)-[:RIVALRY_WITH]->(__Entity__, Person)
# - (__Entity__, Person)-[:DICTATORSHIP_PERIOD]->(__Entity__, TimePeriod)
# - (__Entity__, Person)-[:ROLE]->(__Entity__, Position)
# - (__Entity__, Person)-[:CONQUEST_OF]->(__Entity__, Place, Region)
# - (__Entity__, Person)-[:FOUGHT_AGAINST]->(__Entity__, Organization)
# - (__Entity__, Person)-[:PART_OF]->(__Entity__, Event)
# - (__Entity__, Person)-[:ROSE_TO_POWER]->(__Entity__, Event)
# - (__Entity__, Person)-[:DEFEATED]->(__Entity__, Person)
# - (__Entity__, Person)-[:VICTORY_OVER]->(__Entity__, Person)
# - (__Entity__, Concept)-[:EXISTED_IN]->(__Entity__, Time Period)
# - (__Entity__, Government System)-[:ESTABLISHED_IN]->(__Entity__, Time Period)
# - (__Entity__, Government System)-[:INVOLVES]->(__Entity__, Entities)
# - (__Entity__, Government System)-[:INCLUDES]->(__Entity__, Entity)
# - (__Entity__, Government System)-[:PROMOTES]->(__Entity__, Event)
# - (__Entity__, Person)-[:BELONGS_TO]->(__Entity__, Dynasty)
# - (__Entity__, Person)-[:RULED_DURING]->(__Entity__, Time Period)
# - (__Entity__, Person)-[:MENTIONED_IN]->(__Entity__, Historical Period)
# - (__Entity__, Event)-[:MENTIONED_IN]->(__Entity__, Historical Period)
# - (__Entity__, Event)-[:MENTIONED_IN]->(__Entity__, Chapter)
# - (__Entity__, Dynasty)-[:MENTIONED_IN]->(__Entity__, Historical Period)
# - (__Entity__, Geographical Entity)-[:UNDER]->(__Entity__, Period)
# - (__Entity__, Religion)-[:INTERACTS_WITH]->(__Entity__, Political Entity)
# - (__Entity__, Social Structure)-[:EXISTS_UNDER]->(__Entity__, Period)
# - (__Entity__, Organization)-[:DEFENDS]->(__Entity__, Geographical Feature)
# - (__Entity__, Social Structure)-[:ALSO_KNOWN_AS]->(__Entity__, Social Structure)
# - (__Entity__, Social Structure)-[:UNDER]->(__Entity__, Period)
# - (__Entity__, Political System)-[:EXISTS_DURING]->(__Entity__, Period)
# - (__Entity__, Organization)-[:GROWTH_OF]->(__Entity__, Period)
# - (__Entity__, Religious Practice)-[:ASSOCIATED_WITH]->(__Entity__, Religious Practice)
# - (__Entity__, Cultural Entity)-[:PART_OF]->(__Entity__, Social Structure)
# - (__Entity__, Component)-[:IMPACTS]->(__Entity__, Outcome)
# - (__Entity__, Organization)-[:HAS_COMPONENT]->(__Entity__, System)
# - (__Entity__, System)-[:INCLUDES]->(__Entity__, Component)
# - (__Entity__, Person)-[:ASSOCIATED_WITH]->(__Entity__, Person)
# - (__Entity__, Group)-[:INVOLVED_IN]->(__Entity__, Event)
# - (__Entity__, Time Period)-[:OCCURRED_IN]->(__Entity__, Time Period)
# - (__Entity__, Event)-[:CONTRASTS_WITH]->(__Entity__, Event)
# - (__Entity__, Event)-[:OCCURRED_IN]->(__Entity__, Time Period)
# - (__Entity__, Event)-[:RESULTED_FROM]->(__Entity__, Event)
# - (__Entity__, Event)-[:OCCURRED_TO]->(__Entity__, Time Period)
# - (__Entity__, Entity)-[:EXISTED_IN]->(__Entity__, Time Period)
# - (__Entity__, Entity)-[:INTERACTED_WITH]->(__Entity__, Entity)
# - (__Entity__, Entity)-[:LOCATED_IN]->(__Entity__, Entity, Place, City)
# - (Document, __Entity__)-[:PRESERVED]->(__Entity__, Record)
# - (Document, __Entity__)-[:RECONSTRUCTED_IN]->(__Entity__, Time Period)
# - (__Entity__, Person)-[:TOOK_STEP_IN]->(__Entity__, Activity)
# - (__Entity__, Person)-[:WROTE]->(__Entity__, Work)
# - (__Entity__, Person)-[:LANGUAGE]->(__Entity__, Language)
# - (__Entity__, Work)-[:COMPILED]->(__Entity__, Work)
# - (__Entity__, Work)-[:COVERS_PERIOD]->(__Entity__, TimePeriod)
# - (__Entity__, Work)-[:REFLECTS]->(__Entity__, Topic)
# - (__Entity__, Person)-[:COMPOSED]->(__Entity__, Work)
# - (__Entity__, Person)-[:MENTIONED_IN]->(__Entity__, Work)
# - (__Entity__, Person)-[:PRESERVED_IN]->(__Entity__, Work)
# - (__Entity__, Group)-[:WROTE_IN]->(__Entity__, TimePeriod)
# - (__Entity__, Person)-[:COMPILED]->(__Entity__, Work)
# - (__Entity__, Work)-[:DESCRIBES]->(__Entity__, Topic)
# - (__Entity__, Person)-[:MENTIONED_IN]->(__Entity__, Time Period)
# - (__Entity__, Person)-[:REPRESENTATIVE_OF]->(__Entity__, Profession)
# - (__Entity__, Time Period)-[:DISPLAYED_ACTIVITY]->(__Entity__, Activity)
# - (__Entity__, Time Period)-[:CHARACTERIZED_BY]->(__Entity__, Activity)
# - (__Entity__, Time Period)-[:TIME_SPAN]->(__Entity__, Date Range)
# - (__Entity__, Work)-[:INFLUENCED]->(__Entity__, Group)
# - (__Entity__, Person)-[:AUTHOR_OF]->(__Entity__, Work)
# - (__Entity__, Person)-[:INFLUENCED]->(__Entity__, HistoricalEvent)
# - (__Entity__, Person)-[:WROTE_DURING]->(__Entity__, Time Period)
# - (__Entity__, Person)-[:CONTEMPORARY_OF]->(__Entity__, Person)
# - (__Entity__, Person)-[:ASSOCIATED_WITH]->(__Entity__, Time Period)
# - (__Entity__, Work)-[:ABOUT]->(__Entity__, Entity, Place, City)
# - (__Entity__, Work)-[:HAS_QUALITY]->(__Entity__, Characteristic)
# - (__Entity__, Work)-[:HAS_LIMITATION]->(__Entity__, Limitation)
# - (__Entity__, Work)-[:COVERS]->(__Entity__, Topic)
# - (__Entity__, Person)-[:PRESERVED]->(__Entity__, Narrative)
# - (__Entity__, Organization)-[:HAS_NARRATIVE]->(__Entity__, Event)
# - (__Entity__, Geographical Feature)-[:IS_PART_OF]->(__Entity__, Place, Location, Country)
# - (__Entity__, Geographical Feature)-[:HAS_SIZE]->(__Entity__, Characteristic)
# - (__Entity__, Location)-[:HAS_FEATURE]->(__Entity__, Characteristic)
# - (__Entity__, Location)-[:IS_ACCESSIBLE_FROM]->(__Entity__, Location)
# - (__Entity__, Location)-[:IS_LESS_INVITING_THAN]->(__Entity__, Location)
# - (__Entity__, Location, Region)-[:HAS_RESOURCE]->(__Entity__, Resource)
# - (__Entity__, Location)-[:HAS_CHARACTERISTIC]->(__Entity__, Characteristic)
# - (__Entity__, Location)-[:OCCUPIED_BY]->(__Entity__, Group)
# - (__Entity__, Location)-[:HAS_RESOURCE]->(__Entity__, Resource)
# - (__Entity__, Location)-[:YIELDS]->(__Entity__, Product)
# - (__Entity__, Plant)-[:FLOURISHED_IN]->(__Entity__, Location)
# - (__Entity__, Plant)-[:MORE_PROFITABLE_THAN]->(__Entity__, Activity)
# - (__Entity__, Location)-[:YIELDS]->(__Entity__, Characteristic)
# - (__Entity__, Location)-[:IS_FERTILE]->(__Entity__, Characteristic)
# - (__Entity__, Location)-[:AFFORDED]->(__Entity__, Characteristic)
# - (__Entity__, Activity)-[:PART_OF]->(__Entity__, Industry)
# - (__Entity__, Activity)-[:RANKED_NEXT_TO]->(__Entity__, Activity)
# - (__Entity__, Place, Location)-[:LINKED_TO]->(__Entity__, Location)
# - (__Entity__, Place, Location)-[:SEPARATED_FROM]->(__Entity__, Location)
# - (__Entity__, Place, Location)-[:LOCATED_BETWEEN]->(__Entity__, Location, Region)
# - (__Entity__, Place, Location)-[:HAD_CIVILIZATION]->(__Entity__, Characteristic)
# - (__Entity__, Place, Location)-[:HAS_CIVILIZATION]->(__Entity__, Characteristic)
# - (__Entity__, Place, Location)-[:HAS_CHARACTERISTIC]->(__Entity__, Characteristic)
# - (__Entity__, Place)-[:HAS_CHARACTERISTIC]->(__Entity__, Characteristic)
# - (__Entity__, Place)-[:LOCATED_BETWEEN]->(__Entity__, Location, Region)
# - (__Entity__, Place)-[:HISTORICAL_IMPORTANCE]->(__Entity__, Historical Significance)
# - (__Entity__, People)-[:NAME_ORIGIN]->(__Entity__, Word)
# - (__Entity__, Place, Name)-[:DERIVED_FROM]->(__Entity__, People)
# - (__Entity__, Place, Name)-[:NAMED_AFTER]->(__Entity__, People)
# - (__Entity__, Place, Name)-[:GEOGRAPHICAL_SIGNIFICANCE]->(__Entity__, Place, Geographical Entity)
# - (__Entity__, Place)-[:ADJACENT_TO]->(__Entity__, Place)
# - (__Entity__, Geographical Entity)-[:DENOTES]->(__Entity__, Place, Geographical Entity)
# - (__Entity__, Geographical Entity)-[:HAS_SIGNIFICANCE]->(__Entity__, Characteristic)
# - (__Entity__, Location)-[:ASSOCIATED_WITH]->(__Entity__, Characteristic)
# - (__Entity__, Science)-[:CONTRIBUTES_TO]->(__Entity__, Process)
# - (__Entity__, Artifact Type)-[:ASSOCIATED_WITH]->(__Entity__, Time Period)
# - (__Entity__, Location)-[:LOCATED_IN]->(__Entity__, Location, Region)
# - (__Entity__, Location)-[:LOCATED_NEAR]->(__Entity__, Location)
# - (__Entity__, Person)-[:FOUGHT_AND_HUNTED]->(__Entity__, Animal)
# - (__Entity__, TimePeriod, Time Period)-[:FOLLOWED]->(__Entity__, Time Period)
# - (__Entity__, TimePeriod, Time Period)-[:INTRODUCED]->(__Entity__, Culture)
# - (__Entity__, Material)-[:USED_FOR]->(__Entity__, Activity)
# - (__Entity__, Time Period)-[:LACKED]->(__Entity__, Skill)
# - (__Entity__, Characteristic, Group)-[:ACQUAINTED_WITH]->(__Entity__, Skill)
# - (__Entity__, Material)-[:USED_FOR]->(__Entity__, Object)
# - (__Entity__, Location)-[:PRODUCED]->(__Entity__, Object)
# - (__Entity__, Structure)-[:LOCATED_IN]->(__Entity__, Place, Location, Country)
# - (__Entity__, Structure)-[:MADE_OF]->(__Entity__, Material)
# - (__Entity__, Group)-[:LIVED_IN]->(__Entity__, Location)
# - (__Entity__, Group)-[:BUILT]->(__Entity__, Structure)
# - (__Entity__, Group)-[:BURIED_DEAD_IN]->(__Entity__, Location)
# - (__Entity__, Location)-[:LINED_WITH]->(__Entity__, Material)
# - (__Entity__, Group)-[:HUNTED]->(__Entity__, Animal)
# - (__Entity__, Group)-[:DOMESTICATED]->(__Entity__, Animal)
# - (__Entity__, Group)-[:USED]->(__Entity__, Tool)
# - (__Entity__, Group)-[:MANUFACTURED]->(__Entity__, Artifact)
# - (__Entity__, People)-[:SURVIVED_FROM]->(__Entity__, TimePeriod)
# - (__Entity__, People)-[:MAINTAINED_THEMSELVES_IN]->(__Entity__, Place)
# - (__Entity__, People)-[:PROBABLY]->(__Entity__, Characteristic, Group)
# - (__Entity__, City)-[:EXTENDED_SOUTHWARD_TO]->(__Entity__, Group)
# - (__Entity__, Location)-[:LOCATED_IN]->(__Entity__, Geographical Feature)
# - (__Entity__, Settlement)-[:HAS_TYPE]->(__Entity__, Type)
# - (__Entity__, Civilization)-[:PRECEDES]->(__Entity__, Era)
# - (__Entity__, Era)-[:CHARACTERIZED_BY]->(__Entity__, Characteristic)
# - (__Entity__, Civilization)-[:PRECEDES]->(__Entity__, Civilization)
# - (Document)-[:FIRST_CHUNK]->(Chunk)
# - (Chunk)-[:HAS_ENTITY]->(__Entity__, License)

# %%
user_query = "Who were the main figures in THE EXPANSION OF ROME TO THE UNIFICATION OF THE ITALIAN PENINSULA: c. 509-265 B. C."

# %%
prompt = f"""
You are an expert in Neo4j and historical knowledge retrieval.
Given the following Neo4j database schema comming from the following Cypher query:

    MATCH (n)-[r]->(m) 
    RETURN DISTINCT labels(n) AS source_node, type(r) AS relationship, labels(m) AS target_node

From that query you'll get an schema directly from Neo4j, but knowing the query it comes from contextaulize so you that you know
how to identify the different entities, and relationships

{schema_info}

Generate an optimized Cypher query to retrieve relevant information for the question:
"{user_query}"

Ensure the query is valid, optimized, and does not use unnecessary clauses, and focus on contextualizing what the user is asking
and what you have available in the the scheme, like the following examples:

What are the most important events that ocurred in rome.

Rome is a location, so you might use that if that is an entity or node, and then you can use the relationships that node has to
further construct on the query the user had.
"""

# %%
def generate_cypher_query(prompt):
    """Uses OpenAI to generate a Cypher query based on user input and schema."""
    
    client = openai.OpenAI()

    response = client.chat.completions.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You generate Cypher queries for a Neo4j historical knowledge graph."},
            {"role": "user", "content": prompt}
        ]
    )

    cypher_query = response.choices[0].message.content
    return cypher_query.strip()

cypher_query = generate_cypher_query(prompt)
print("Generated Cypher Query:\n", cypher_query)
# Out:
# Generated Cypher Query:
#  Based on the question, to get the main figures in THE EXPANSION OF ROME TO THE UNIFICATION OF THE ITALIAN PENINSULA: c. 509-265 B. C., we can potentially look for the `Person` entities who had significant `HAS_TITLE`, `HAS_ROLE`, `HELD_POSITION`, `GUIDED` or `INVOLVED_IN` relationships during this `TimePeriod`. We can also focus on the entities (`Person` or `Event`) that `:MENTIONED_IN` the historical period of the expansion of Rome.
#
# Here is the potential Cypher query:
#
# ```cypher
# MATCH (p:__Entity__, Person)-[r:HAS_TITLE|:HAS_ROLE|:HELD_POSITION|:GUIDED|:INVOLVED_IN|:MENTIONED_IN]->(e:Event)
# WHERE EXISTS {
#     MATCH (e:Event)<--(:TimePeriod { name: 'THE EXPANSION OF ROME TO THE UNIFICATION OF THE ITALIAN PENINSULA: c. 509-265 B. C.' })
#     OPTIONAL MATCH (e:Event)-->(:Location { name: 'Rome' })
# }
# RETURN p.name as Person, type(r) as Relation, e.name as Event
# ```
#
# This query finds the `Person` entities who had significant roles or were mentioned during the specified period, then returns their names, relationship type, and associated `Event` names. It filters also to ensure that the events are tied to the location 'Rome'. Because the event might not be linked with 'Rome', OPTIONAL MATCH is used.
#
# Note: This query assumes that there are node labels `Location`, `Person` and `Event`, and there exist properties `name` on the nodes. It is necessary to adjust the query to your specific schema if the labels and properties are defined differently.

# %%
cypher_query="""MATCH (p:__Entity__, Person)-[r:HAS_TITLE|:HAS_ROLE|:HELD_POSITION|:GUIDED|:INVOLVED_IN|:MENTIONED_IN]->(e:Event)
WHERE EXISTS {
    MATCH (e:Event)<--(:TimePeriod { name: 'THE EXPANSION OF ROME TO THE UNIFICATION OF THE ITALIAN PENINSULA: c. 509-265 B. C.' })
    OPTIONAL MATCH (e:Event)-->(:Location { name: 'Rome' }) 
}
RETURN p.name as Person, type(r) as Relation, e.name as Event
"""

# %%
def query_neo4j(cypher_query):
    driver = GraphDatabase.driver(uri, auth=(username, password))
    with driver.session() as session:
        result = session.run(cypher_query)
        return [record.data() for record in result]

results = query_neo4j(cypher_query)
print(results)
# Out:
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# Cell In[16], line 7
#       4         result = session.run(cypher_query)
#       5         return [record.data() for record in result]
# ----> 7 results = query_neo4j(cypher_query)
#       8 print(results)
#
# Cell In[16], line 4, in query_neo4j(cypher_query)
#       2 driver = GraphDatabase.driver(uri, auth=(username, password))
#       3 with driver.session() as session:
# ----> 4     result = session.run(cypher_query)
#       5     return [record.data() for record in result]
#
# File c:\Users\juank\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:328, in Session.run(self, query, parameters, **kwargs)
#     326 bookmarks = self._get_bookmarks()
#     327 parameters = dict(parameters or {}, **kwargs)
# --> 328 self._auto_result._run(
#     329     query,
#     330     parameters,
#     331     self._config.database,
#     332     self._config.impersonated_user,
#     333     self._config.default_access_mode,
#     334     bookmarks,
#     335     self._config.notifications_min_severity,
#     336     self._config.notifications_disabled_classifications,
#     337 )
#     339 return self._auto_result
#
# File c:\Users\juank\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     234 self._pull()
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File c:\Users\juank\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\result.py:430, in Result._attach(self)
#     428 if self._exhausted is False:
#     429     while self._attached is False:
# --> 430         self._connection.fetch_message()
#
# File c:\Users\juank\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File c:\Users\juank\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_message(self)
#     860 # Receive exactly one message
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#     866 return res
#
# File c:\Users\juank\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt5.py:1208, in Bolt5x7._process_message(self, tag, fields)
#    1206 self._enrich_error_diagnostic_record(summary_metadata)
#    1207 try:
# -> 1208     response.on_failure(summary_metadata or {})
#    1209 except (ServiceUnavailable, DatabaseUnavailable):
#    1210     if self.pool:
#
# File c:\Users\juank\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input ',': expected a parameter, '&', ')', ':', 'WHERE', '{' or '|' (line 1, column 20 (offset: 19))
# "MATCH (p:__Entity__, Person)-[r:HAS_TITLE|:HAS_ROLE|:HELD_POSITION|:GUIDED|:INVOLVED_IN|:MENTIONED_IN]->(e:Event)"
#                     ^}

# %%
context = f"""
Structured Data:
{results}
"""
# Similar Historical Context:
# {similar_nodes}

final_prompt = f"""
You are a historian assistant. Using the structured data and similar context retrieved from a Neo4j knowledge graph, generate a detailed historical answer for the question:
"{user_query}"

Context:
{context}

Provide a well-structured, factual, and engaging historical explanation.
"""

# %%
def generate_historical_response(final_prompt):

    client = openai.OpenAI()

    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "system", "content": "You are a historian AI assistant."},
                  {"role": "user", "content": context}]
    )

    return response.choices[0].message.content.strip()

# Generate a response
historical_answer = generate_historical_response(final_prompt)
print("Final Response:\n", historical_answer)
